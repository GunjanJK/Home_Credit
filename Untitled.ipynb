# %%
import pandas as pd
import numpy as np

# %%
cc_bal = pd.read_csv('credit_card_balance.csv')

# %%
c_c_b = cc_bal.loc[:,['SK_ID_PREV','SK_ID_CURR','SK_DPD','SK_DPD_DEF']]

# %%
c_c_b.to_csv('d3.csv')

# %%
bue = pd.read_csv('bureau.csv')

# %%
bue.columns
# Out:
# Index(['SK_ID_CURR', 'SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY',
#        'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE',
#        'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG',
#        'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT',
#        'AMT_CREDIT_SUM_OVERDUE', 'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY'],
#       dtype='object')

# %%
bue_f = bue.loc[:,['SK_ID_CURR','SK_ID_BUREAU','CREDIT_DAY_OVERDUE','CNT_CREDIT_PROLONG']]

# %%
bue_f.to_csv('d4.csv')

# %%
b_b = pd.read_csv('bureau_balance.csv')

# %%
b_b_f = b_b.loc[:,['SK_ID_BUREAU','STATUS']]

# %%
b_b_f.to_csv('d5.csv')

# %%
bue_f.shape
# Out:
# (1716428, 4)

# %%
b_b_f.shape
# Out:
# (27299925, 2)

# %%
data_3 = pd.merge(bue_f,b_b_f, on='SK_ID_BUREAU')

# %%
data_3.head(10)
# Out:
#    SK_ID_CURR  SK_ID_BUREAU  CREDIT_DAY_OVERDUE  CNT_CREDIT_PROLONG STATUS
# 0      380361       5715448                   0                   0      C
# 1      380361       5715448                   0                   0      C
# 2      380361       5715448                   0                   0      C
# 3      380361       5715448                   0                   0      C
# 4      380361       5715448                   0                   0      C
# 5      380361       5715448                   0                   0      C
# 6      380361       5715448                   0                   0      C
# 7      380361       5715448                   0                   0      C
# 8      380361       5715448                   0                   0      C
# 9      380361       5715448                   0                   0      0

# %%
data_3.isnull().sum()
# Out:
# SK_ID_CURR            0
# SK_ID_BUREAU          0
# CREDIT_DAY_OVERDUE    0
# CNT_CREDIT_PROLONG    0
# STATUS                0
# dtype: int64

# %%
data_3.to_csv('data_3.csv')

# %%
aa = pd.read_csv('d1.csv')

# %%
bb = pd.read_csv('d2.csv')

# %%
aa.shape
# Out:
# (13605401, 4)

# %%
comb_1 = pd.merge(bb,data1, on='SK_ID_CURR', how='left')

# %%
bb.sort_values('SK_ID_CURR')
# Out:
#          SK_ID_PREV  SK_ID_CURR  SK_DPD  SK_DPD_DEF
# 8531326     1851984      100001       0           0
# 1891462     1851984      100001       7           7
# 8789081     1369693      100001       0           0
# 4704415     1369693      100001       0           0
# 7167007     1369693      100001       0           0
# 4928574     1851984      100001       0           0
# 1261679     1851984      100001       0           0
# 7823681     1369693      100001       0           0
# 2197888     1369693      100001       0           0
# 9849444     1038818      100002       0           0
# 1216849     1038818      100002       0           0
# 9510102     1038818      100002       0           0
# 7403606     1038818      100002       0           0
# 9514583     1038818      100002       0           0
# 9517658     1038818      100002       0           0
# 7714429     1038818      100002       0           0
# 9793374     1038818      100002       0           0
# ...

# %%
bb.head(10)

# %%
bb.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data1 = aa[aa['Days_Delayed']>0]

# %%
data1.shape
# Out:
# (1146669, 3)

# %%
data1.head()
# Out:
#     SK_ID_PREV  SK_ID_CURR  Days_Delayed
# 4      2714724      167756          17.0
# 19     2329072      183463           6.0
# 30     1840786      175114           2.0
# 45     1644499      111587          15.0
# 47     1895324      131465           7.0

# %%
aa.sort_values('SK_ID_CURR')
# Out:
#           Unnamed: 0  SK_ID_PREV  SK_ID_CURR  Days_Delayed
# 3458712      3458712     1369693      100001         -11.0
# 3435373      3435373     1851984      100001           0.0
# 2624024      2624024     1369693      100001          -9.0
# 1761012      1761012     1851984      100001           0.0
# 3774071      3774071     1851984      100001          11.0
# 1478621      1478621     1369693      100001          -6.0
# 2568722      2568722     1369693      100001         -36.0
# 2163032      2163032     1038818      100002         -27.0
# 504426        504426     1038818      100002         -15.0
# 699804        699804     1038818      100002         -19.0
# 1675768      1675768     1038818      100002         -24.0
# 3594829      3594829     1038818      100002         -27.0
# 210205        210205     1038818      100002         -20.0
# 2144879      2144879     1038818      100002         -22.0
# 2785201      2785201     1038818      100002         -19.0
# ...

# %%
aa.head(20)

# %%
c_c_b.drop('SK_ID_PREV', axis=1, inplace=True)

# %%
c_c_b.shape
# Out:
# (3840312, 3)

# %%
data_2 = pd.merge(c_c_b,aa,on='SK_ID_CURR', how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-33-85eaf451ba68> in <module>()
# ----> 1 data_2 = pd.merge(c_c_b,aa,on='SK_ID_CURR', how='left')
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          copy=copy, indicator=indicator,
#      60                          validate=validate)
# ---> 61     return op.get_result()
#      62
#      63
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     565                 self.left, self.right)
#     566
# --> 567         join_index, left_indexer, right_indexer = self._get_join_info()
#     568
#     569         ldata, rdata = self.left._data, self.right._data
#
# ...
